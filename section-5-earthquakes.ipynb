# %% [markdown]
# # Source
# https://earthquake.usgs.gov/earthquakes/search/
#
# # Data
# https://raw.githubusercontent.com/carmengg/eds220-hwk-1/main/data/earthquake_data.csv

# %% [markdown]
# # Brainstorming
# # Steps
#
# 1) Import data and geospatial data
# 2) Clean and filter
# 3) Change data lat/long to geospatial
# 4)
#
#
#
#
#
# 1) Year for 2014 (all)
# 2) Mag of 6.5 or greater - Filter
# 3)

# %%
#import libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/carmengg/eds220-hwk-1/main/data/earthquake_data.csv')
data
# Out:
#                            time   latitude   longitude   depth   mag  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.20  1.10
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.00  1.33
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.10  1.30
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.50  0.80
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.59  1.34
# ...                         ...        ...         ...     ...   ...
# 120103  2014-12-01 00:10:16.000  60.963900 -146.762900   14.80  3.80
# 120104  2014-12-01 00:09:39.000  58.869100 -154.415900  108.40  2.40
# 120105  2014-12-01 00:09:25.350  38.843498 -122.825836    2.37  0.43
# 120106  2014-12-01 00:05:54.000  65.152100 -148.992000    9.50  0.40
# 120107  2014-12-01 00:04:05.000  60.227200 -147.024500    2.50  1.60
#
#                 id                              place        type
# 0       ak11155107  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %%
$

# %%
data.head()
# Out:
#                       time   latitude  longitude  depth   mag          id  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10  ak11155107
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33  nn00436847
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30  ak11151142
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80  ak11151135
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34  ci37171541
#
#                                place        type
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# 1            32km S of Alamo, Nevada  earthquake
# 2   12km NNW of North Nenana, Alaska  earthquake
# 3         22km S of Cantwell, Alaska  earthquake
# 4       10km WNW of Progreso, Mexico  earthquake

# %%
mag65 = data[data['mag'] >= 6.5]
#mag65

# %%
shape_data = os.path.join('data','ne_110m_admin_0_countries.shp')

shape_data = gpd.read_file(shape_data)

# %%
shape_data
# Out:
#           featurecla  scalerank  LABELRANK                   SOVEREIGNT  \
# 0    Admin-0 country          1          6                         Fiji
# 1    Admin-0 country          1          3  United Republic of Tanzania
# 2    Admin-0 country          1          7               Western Sahara
# 3    Admin-0 country          1          2                       Canada
# 4    Admin-0 country          1          2     United States of America
# ..               ...        ...        ...                          ...
# 172  Admin-0 country          1          5           Republic of Serbia
# 173  Admin-0 country          1          6                   Montenegro
# 174  Admin-0 country          1          6                       Kosovo
# 175  Admin-0 country          1          5          Trinidad and Tobago
# 176  Admin-0 country          1          3                  South Sudan
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE TLC  \
# ...

# %%
mag65.geom = gpd.points_from_xy(mag65.longitude,mag65.latitude)
geom
# Out:
# /tmp/ipykernel_1177139/2575780579.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   mag65.geom = gpd.points_from_xy(mag65.longitude,mag65.latitude)
# <GeometryArray>
# [ <POINT (167.249 -13.863)>,   <POINT (-58.927 14.668)>,
#     <POINT (82.586 35.905)>,  <POINT (167.372 -15.069)>,
#  <POINT (-177.881 -32.908)>,  <POINT (-70.702 -19.981)>,
#   <POINT (-125.134 40.829)>,   <POINT (127.367 27.431)>,
#   <POINT (-127.732 49.639)>,   <POINT (155.024 -6.755)>,
#    <POINT (155.087 -6.656)>,  <POINT (-100.972 17.397)>,
#     <POINT (8.722 -53.497)>,  <POINT (162.052 -11.128)>,
#   <POINT (162.051 -11.463)>,   <POINT (162.148 -11.27)>,
#    <POINT (-85.878 11.642)>,    <POINT (154.95 -6.788)>,
#    <POINT (155.048 -6.586)>,  <POINT (-70.493 -20.571)>,
#   <POINT (-70.576 -20.311)>,  <POINT (-70.946 -19.893)>,
#    <POINT (-70.769 -19.61)>,    <POINT (25.389 40.289)>,
# ...

# %%
mag65.head()
# Out:
#                           time  latitude  longitude   depth  mag          id  \
# 9062   2014-01-01 16:03:29.000  -13.8633   167.2490  187.00  6.5  usc000lvb5
# 12142  2014-02-18 09:27:13.120   14.6682   -58.9272   14.83  6.5  usc000mskt
# 14025  2014-02-12 09:19:49.060   35.9053    82.5864   10.00  6.9  usc000mnvj
# 15979  2014-02-07 08:40:13.550  -15.0691   167.3721  122.00  6.5  usc000mjye
# 17606  2014-02-02 09:26:37.820  -32.9076  -177.8806   44.26  6.5  usc000mfm0
#
#                                             place        type
# 9062                      32km W of Sola, Vanuatu  earthquake
# 12142            172km NNE of Bathsheba, Barbados  earthquake
# 14025                   272km ESE of Hotan, China  earthquake
# 15979                34km E of Port-Olry, Vanuatu  earthquake
# 17606  189km SSE of L'Esperance Rock, New Zealand  earthquake

# %%
mag65.geom.plt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 geom.plt()
#
# AttributeError: 'GeometryArray' object has no attribute 'plt'
